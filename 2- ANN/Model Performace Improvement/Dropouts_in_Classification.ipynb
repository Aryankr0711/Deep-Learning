# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification

import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
data=make_classification(n_samples=5000, n_features=20)

# %%
X=data[0]
y=data[1]

# %%
y.shape, X.shape
# Out:
# ((5000,), (5000, 20))

# %%
model=Sequential()
model.add(Dense(64, activation='relu', input_dim=20))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
adam=Adam(learning_rate=0.2)
model.compile(loss='binary_crossentropy',optimizer=adam)

# %%
history=model.fit(X, y, validation_split=0.2, epochs=500)
# Out:
# Epoch 1/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6386 - val_loss: 0.7029
# Epoch 2/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7244 - val_loss: 0.6973
# Epoch 3/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6969 - val_loss: 0.6964
# Epoch 4/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6965 - val_loss: 0.6936
# Epoch 5/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6963 - val_loss: 0.6927
# Epoch 6/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6973 - val_loss: 0.6977
# Epoch 7/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6970 - val_loss: 0.6927
# Epoch 8/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6978 - val_loss: 0.6927
# Epoch 9/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6992 - val_loss: 0.6927
# Epoch 10/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6961 - val_loss: 0.6927
# Epoch 11/500
# ...

# %%
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Val')
plt.legend()
plt.show()

# %%
model=Sequential()
model.add(Dense(64, activation='relu', input_dim=20))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
adam=Adam(learning_rate=0.2)
model.compile(loss='binary_crossentropy',optimizer=adam)

# %%
history=model.fit(X, y, validation_split=0.2, epochs=500)
# Out:
# Epoch 1/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.1499 - val_loss: 0.6814
# Epoch 2/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8719 - val_loss: 0.6939
# Epoch 3/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7067 - val_loss: 0.7096
# Epoch 4/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7076 - val_loss: 0.6942
# Epoch 5/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6971 - val_loss: 0.6941
# Epoch 6/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7824 - val_loss: 0.7111
# Epoch 7/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7054 - val_loss: 0.6930
# Epoch 8/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6994 - val_loss: 0.7054
# Epoch 9/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7008 - val_loss: 0.6976
# Epoch 10/500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6963 - val_loss: 0.6957
# Epoch 11/500
# ...

# %%
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Val')
plt.legend()
plt.show()

# %%
plt.plot(history.history['val_loss'], label='Val')
plt.legend()
plt.show()
