# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
mat1=np.random.random(3)
mat2=np.random.random(3)

# %%
Vector3D1=[]
Vector3D2=[]
for i in range(1000):
  mat1=np.random.normal(size=3)
  mat2=np.random.normal(size=3)
  Vector3D1.append(mat1)
  Vector3D2.append(mat2)

# %%
arr1 = np.array(Vector3D1)
arr2 = np.array(Vector3D2)

Plot_3D = arr1 * arr2

# %%
len(Plot_3D)
# Out:
# 1000

# %%
sns.histplot(Plot_3D)
plt.show()

# %%
Vector3D1=[]
Vector3D2=[]
for i in range(1000):
  mat1=np.random.normal(size=100)
  mat2=np.random.normal(size=100)
  Vector3D1.append(mat1)
  Vector3D2.append(mat2)

# %%
arr1 = np.array(Vector3D1)
arr2 = np.array(Vector3D2)

Plot_100D = np.sum(arr1 * arr2, axis=1)

# %%
sns.histplot(Plot_100D)
plt.show()

# %%
Vector3D1=[]
Vector3D2=[]
for i in range(1000):
  mat1=np.random.normal(size=1000)
  mat2=np.random.normal(size=1000)
  Vector3D1.append(mat1)
  Vector3D2.append(mat2)

# %%
arr1 = np.array(Vector3D1)
arr2 = np.array(Vector3D2)

Plot_1000D = np.sum(arr1 * arr2, axis=1)

# %%
sns.histplot(Plot_1000D)
plt.show()

# %%
sns.histplot(Plot_1000D, label='1000 D', color='red')
sns.histplot(Plot_3D, label='3 D')
sns.histplot(Plot_100D, label='100 D')
plt.show()

# %% [markdown]
# # So we conclude that with change in dimesnion
